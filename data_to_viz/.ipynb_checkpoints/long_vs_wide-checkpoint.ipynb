# %% [markdown]
# # Long vs Wide format

# %% [markdown]
# ## Tidy data

# %% [markdown]
# ![Tidy data](https://d33wubrfki0l68.cloudfront.net/6f1ddb544fc5c69a2478e444ab8112fb0eea23f8/91adc/images/tidy-1.png)
#
# - Inherent structure of pandas data frames -> ideal for pandas functions: plotting, aggregating, tranforming, merging
# - Necessary to work with data frame based plotting libraries e.g. seaborn, plotly
# - Ideal structure for machine learning: e.g. classificaion each row is an observation described by a set of features (variables)

# %% [markdown]
# ### Why tidy data?
# - Inherent structure of pandas data frames -> ideal for pandas functions: plotting, aggregating, tranforming, merging
# - Necessary to work with data frame based plotting libraries e.g. seaborn, plotly
# - Ideal structure for machine learning in scikit: e.g. classificaion each row is an observation described by a set of features (variables)

# %% [markdown]
# #### !!! If your data is tidy, you can easily switch between wide and long formats
# - In the **long format**, there is a single value column and another column that contains _**the variable name as a category_** for each of the values. This format is great for plotting with seaborn.
#
# - In the **wide format**, each variable has its own column. This format is great for calculating descriptive statistics or for applying machine learning with sklearn.

# %% [markdown]
# ## Long vs. wide tables
#
# And the importance of knowing what is an observation!

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Each observation is a penguin

# %%
# !pwd
# Out:
# /Users/paula/Desktop/long_vs_wide

# %%
df = pd.read_csv('../../SPICED/teaching/pga_curriculum/01_week/plotting_with_python_I/penguins_simple.csv', sep=";")
df.head()
# Out:
#   Species  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0  Adelie                39.1               18.7                181.0
# 1  Adelie                39.5               17.4                186.0
# 2  Adelie                40.3               18.0                195.0
# 3  Adelie                36.7               19.3                193.0
# 4  Adelie                39.3               20.6                190.0
#
#    Body Mass (g)     Sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 3         3450.0  FEMALE
# 4         3650.0    MALE

# %%
# clean the column names
df.columns = df.columns.str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
# we have to create an id column to keep track of each penguin
df['penguin_id'] = range(len(df))
df.head()
# Out:
#   species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0  Adelie              39.1             18.7              181.0       3750.0
# 1  Adelie              39.5             17.4              186.0       3800.0
# 2  Adelie              40.3             18.0              195.0       3250.0
# 3  Adelie              36.7             19.3              193.0       3450.0
# 4  Adelie              39.3             20.6              190.0       3650.0
#
#       sex  penguin_id
# 0    MALE           0
# 1  FEMALE           1
# 2  FEMALE           2
# 3  FEMALE           3
# 4    MALE           4

# %%
sns.scatterplot(data = df, x = 'culmen_length_mm', y = 'culmen_depth_mm', hue = 'species', style = 'sex')

# %%
sns.pairplot(data=df, hue='species')

# %% [markdown]
# ### But what if:each observation is a measurement of penguin's bill, and culmen_length, culmen_depth are categories of culmen measurements

# %% [markdown]
# ## `df.melt`: from wide to long
# - **id_vars**: Column(s) to use as identifier variables
# - **value_vars**: Column(s) to unpivot. If not specified, uses all columns that are not set as id_vars.
# - **var_name**: Name to use for the ‘variable’ column.
# - **value_name**: Name to use for the ‘value’ column.

# %%
df.columns
# Out:
# Index(['species', 'culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm',
#        'body_mass_g', 'sex', 'penguin_id'],
#       dtype='object')

# %%
df_melted = df.melt(id_vars=['penguin_id','sex', 'species'],  # column names from the original df
        value_vars=['culmen_length_mm', 'culmen_depth_mm'], # column names from the original df
        var_name='bill_measurement',  # new column name for the variable column
        value_name='value_mm')    # new column name for the values column
df_melted
# Out:
#      penguin_id     sex species  bill_measurement  value_mm
# 0             0    MALE  Adelie  culmen_length_mm      39.1
# 1             1  FEMALE  Adelie  culmen_length_mm      39.5
# 2             2  FEMALE  Adelie  culmen_length_mm      40.3
# 3             3  FEMALE  Adelie  culmen_length_mm      36.7
# 4             4    MALE  Adelie  culmen_length_mm      39.3
# ..          ...     ...     ...               ...       ...
# 661         328  FEMALE  Gentoo   culmen_depth_mm      13.7
# 662         329  FEMALE  Gentoo   culmen_depth_mm      14.3
# 663         330    MALE  Gentoo   culmen_depth_mm      15.7
# 664         331  FEMALE  Gentoo   culmen_depth_mm      14.8
# 665         332    MALE  Gentoo   culmen_depth_mm      16.1
#
# [666 rows x 5 columns]

# %% [markdown]
# - Often used for plotting things with seaborn (except the pairplot)

# %%
sns.boxplot(data=df_melted, y='value_mm', x='bill_measurement', hue = 'species')

# %%
sns.violinplot(data=df_melted, y='value_mm', x='bill_measurement', hue = 'sex', split = True)

# %% [markdown]
# ## ( `df.pivot`: from long to wide)

# %%
df_melted.pivot(index='penguin_id', columns='bill_measurement', values='value_mm')
# Out:
# bill_measurement  culmen_depth_mm  culmen_length_mm
# penguin_id
# 0                            18.7              39.1
# 1                            17.4              39.5
# 2                            18.0              40.3
# 3                            19.3              36.7
# 4                            20.6              39.3
# ...                           ...               ...
# 328                          13.7              47.2
# 329                          14.3              46.8
# 330                          15.7              50.4
# 331                          14.8              45.2
# 332                          16.1              49.9
#
# [333 rows x 2 columns]

# %% [markdown]
# ### More practical example of "untidy" data in a very wide format: Gapminder data set
# - Your job is to melt this data into a longer format so that it's easier to work with and merge with other tables in the Animated Scatterplot Exercise in the course material. https://krspiced.pythonanywhere.com/chapters/project_gapminder/long_vs_wide.html#animated-scatterplot-exercise

# %%
import requests
from bs4 import BeautifulSoup

# %%
headers = {
  'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.132 Safari/537.36'
}
res = requests.get('https://y.qq.com/n/yqq/song/001J5QJL1pRQYB.html', headers=headers)
soup = BeautifulSoup(res.text, 'html.parser')
comments = soup.find_all('p', class_='c_tx_normal comment__text js_hot_text')

for comment in comments:
  print(comment.text)

# %% [raw]
# # right click - > page source -> and command + f -> there is comments but no content of comments on the page.
# # XHR 全称 XMLHttpRequest，它是浏览器内置的对象，使得 JavaScript 可以发送 HTTP 请求。XHR 和AJAX 技术的结合，可以使网页在不刷新的情况下局部更新页面内容，加快网页的展示。
# 接下来，跟上我的操作，我们一起在 XHR 中寻找 QQ 音乐的评论数据。
#
# 首先点击 Network 中的 XHR 过滤其他类型的请求。可以看到，仍然有很多的请求，我们要从中找到评论的数据。笨一点的方法是一条一条的查看，直到找到评论的数据，但这样耗时又耗力。
#
# 聪明一点的方法是通过名称和数据大小来找，既然是评论的数据，请求名称中可能会带有 comment（评论）。并且评论有很多，数据大小应该会很大（65.8 KB），这样我们就能极大地缩小查找范围。
#
# 还有一个小技巧是：当我们要找的数据有分页时，我们可以先将请求记录清空，再点击下一页，这样就只会出现评论数据的请求了。
#
# 根据上面说的小技巧，我们很快就找到了目标。我们来确认一下是否正确：点击这条请求，然后点击 Preview（预览）查看数据。数据有很多，我们需要一层一层地展开。
#
# 评论数据就在 comment 下的 commentlist 中，commentlist 中的每一项都有 nick（昵称）、avatarurl（头像）、rootcommentcontent（评论内容）等数据。至此，我们可以确认精彩评论的数据就是通过它获取的。

# %% [markdown]
# 我们接下来点击 Headers 里的 General 看看评论数据是如何获取到的。
# Request URL 是请求的链接，也就是 API 的链接。Request Method 是请求方式，这里用的是 GET。Status Code 是状态码，200 表示成功，之前说过。其他两个我们无需关注。
#
# 我们在浏览器打开这个链接，通过 ctrl + f 搜索评论的内容，发现我们需要的评论数据就在其中。数据的内容既有字典也有列表，看上去很是复杂。
#
# 既然找到了获取评论数据的真正链接，接下来我们就可以通过爬虫来爬取数据了。我们仍然使用 requests.get() 方法获取刚才找到的 API 地址，代码如下：

# %%
headers = {
  'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.132 Safari/537.36'
}
res = requests.get('https://c.y.qq.com/base/fcgi-bin/fcg_global_comment_h5.fcg?g_tk=5381&loginUin=0&hostUin=0&format=json&inCharset=utf8&outCharset=GB2312&notice=0&platform=yqq.json&needNewCode=0&cid=205360772&reqtype=2&biztype=1&topid=212877900&cmd=8&needmusiccrit=0&pagenum=0&pagesize=25&lasthotcommentid=&domain=qq.com&ct=24&cv=10101010', headers=headers)
#print(res.text) # this is a dictionary
type(res.json()),res.json()
# Out:
# (dict,
#  {'allow_comment': 1,
#   'allow_song': 0,
#   'auth': 0,
#   'blackuin': 0,
#   'code': 0,
#   'comment': {'commentlist': [{'avatarurl': 'https://thirdwx.qlogo.cn/mmopen/vi_32/SsQqiaJQngK2T9tuLAhgV14XkLxEsQ01aia5Fqg6VRRzvFAKibvvNRfGjjibgVFe0Jyy03icv0uG4iaC0agZgNk5UamA/132',
#      'commentid': 'song_212877900_1152921504898804583_1618985736',
#      'commit_state': 2,
#      'enable_delete': 0,
#      'encrypt_rootcommentuin': 'oK6kowEAoK4z7ecqNecz7e4Foz**',
#      'encrypt_uin': 'oK6kowEAoK4z7ecqNecz7e4Foz**',
#      'identity_pic': '',
#      'identity_type': 0,
#      'is_hot': 1,
#      'is_hot_cmt': 0,
#      'is_medal': 0,
#      'is_stick': 0,
#      'ispraise': 0,
#      'middlecommentcontent': None,
#      'nick': 'kendall0408',
#      'permission': 0,
#      'praisenum': 0,
#      'root_enable_delete': 0,
#      'root_identity_pic': '',
#      'root_identity_type': 0,
#      'root_is_stick': 0,
#      'rootcommentcontent': '笑死，你根本配不上我，姐就是女王',
# ...

# %% [raw]
# https://www.convertonline.io/convert/query-string-to-json # convert string to json

# %%
params = {
  "{\n\"allow_comment\" : 1,\n\"allow_song\" : 0,\n\"auth\" : 0,\n\"blackuin\" : 0,\n\"code\" : 0,\n\"comment\" : {\n\"commentlist\" : [\n{\n\"avatarurl\" : \"http://thirdqq.qlogo.cn/g?b":"sdk",
  "k":[
    "997bzCCibfRCItQWDsmqy2w",
    "aVdTHyI38IM3fjjTDN82cg",
    "997bzCCibfRCItQWDsmqy2w",
    "R6zqB8A3Qwpp9kKgPwcK8Q",
    "Xia9eYkCicPK3ibNDzaicrpK3g",
    "8LbibX75fBEKBjgNJ3w4nKQ",
    "Liahfp7lQhVxaiboANbgCVIA",
    "XAv6ibvOFjAhMbgIZhndK7w",
    "iafOpG5TllkEq84MT8d3zsQ",
    "6yHWaYGFGp3kvnnshvp3nQ",
    "SZzU4PpDZxW6YeyCOQfTlw",
    "P0FicyNeYkvib8jqmtlTQicZg",
    "997bzCCibfRCItQWDsmqy2w",
    "02P0OOWDvtgIopQFJxIJcw",
    "02P0OOWDvtgIopQFJxIJcw",
    "dQ81V9R1PYCLPQnSbSyAMg",
    "ibmAzoYzh2xPBNRjLghxLFQ",
    "r7lyVMibLUvDIxoVSP8smRw",
    "NEicub1uUhiaIeBJ9ArwVNRg",
    "SKakOBwwjWRF4lL4gGv6ww",
    "NEicub1uUhiaIeBJ9ArwVNRg",
    "NEicub1uUhiaIeBJ9ArwVNRg",
    "maTVe8sic9u2U7adxibDib4tg",
    "YWXvlEMm70zblj9LffOL5A",
    "6e3qdR9uu7AiafSYPXNmSbA",
    "WNdO32UXWRnnekSZ061Uibg",
    "vAF5ZYXKh8eETD6MS5yVRQ",
    "UicezmszjvSBQHlyu80xQLw",
    "BtWianqZkRnT4PEmkt8urIg",
    "sppXooq47yLn3BpVz4rcyw",
    "GrwnaA53RTOJsOjttfnyvg",
    "0y4MTYdYneRDbcqnpibgLEQ",
    "s1Kx1ibpWCvFEiahRtXiav4Iw",
    "cMWsQMVxWC7kiabicaxU1Yng"
  ],
  "s":[
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140",
    "140"
  ],
  "t":[
    "1615538975\",\n\"commentid\" : \"song_212877900_1242076300_1618904501\",\n\"commit_state\" : 2,\n\"enable_delete\" : 0,\n\"encrypt_rootcommentuin\" : \"oK-Pownl7wozon**\",\n\"encrypt_uin\" : \"oK-Pownl7wozon**\",\n\"identity_pic\" : \"\",\n\"identity_type\" : 0,\n\"is_hot\" : 1,\n\"is_hot_cmt\" : 0,\n\"is_medal\" : 0,\n\"is_stick\" : 0,\n\"ispraise\" : 0,\n\"middlecommentcontent\" : null,\n\"nick\" : \"592\",\n\"permission\" : 0,\n\"praisenum\" : 0,\n\"root_enable_delete\" : 0,\n\"root_identity_pic\" : \"\",\n\"root_identity_type\" : 0,\n\"root_is_stick\" : 0,\n\"rootcommentcontent\" : \"哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈\",\n\"rootcommentid\" : \"song_212877900_1242076300_1618904501\",\n\"rootcommentnick\" : \"@592\",\n\"score\" : 0,\n\"taoge_topic\" : \"\",\n\"taoge_url\" : \"\",\n\"time\" : 1618904501,\n\"user_type\" : \"\",\n\"vipicon\" : \"\"\n},\n{\n\"avatarurl\" : \"https://thirdwx.qlogo.cn/mmopen/vi_32/DYAIOgq83erBhh6ibCNiahiaHtOicc3VDsWrHs7PhT3todicDGVzQVBG6HzTaZib42FhSDDWxkSKDcgMaFW8YwHKwHtA/132\",\n\"commentid\" : \"song_212877900_1152921504931576064_1618903661\",\n\"commit_state\" : 2,\n\"enable_delete\" : 0,\n\"encrypt_rootcommentuin\" : \"oK
" : 0,\n\"taoge_topic\" : \"\",\n\"taoge_url\" : \"\",\n\"time\" : 1516205346,\n\"user_type\" : \"\",\n\"vipicon\" : \"\"\n}\n],\n\"commenttotal\" : 3227\n},\n\"lastscore\" : 0,\n\"morecomment\" : 1,\n\"msg_comment\" : {\n\"commentlist\" : null,\n\"commenttotal\" : 0\n},\n\"no_copyright\" : 0,\n\"showYuerenTip\" : 0,\n\"subcode\" : 0,\n\"superadmin\" : 0,\n\"taoge_topic\" : \"\",\n\"topic_name\" : \"等你下课\",\n\"topid\" : \"212877900\"\n}# convert string to json\nhttps://www.convertonline.io/convert/query-string-to-json # convert string to json\n​"
  ]
}

# %%
data = res.json()

# %%
data['comment']['commentlist'][0]['rootcommentcontent']
# Out:
# '笑死，你根本配不上我，姐就是女王'

# %%
data['comment']['commentlist'][0]['rootcommentnick']
# Out:
# '@kendall0408'

# %%
for nick in data['comment']['commentlist']:
    if 'rootcommentcontent' in nick:
        print (nick['rootcommentnick'],nick['rootcommentcontent'])
# Out:
# @kendall0408 笑死，你根本配不上我，姐就是女王
# @kendall0408 想起了高中那场没有结果的暗恋
# @。不考上大学不改名 你有看过我吗
# @无晴 又来了
# @喵哥 暗恋时《等你下课》
# 热恋时《告白气球》
# 分手时《不爱我就拉倒》
# 分手后《说好不哭》
# Jay还是那个最懂青春的人[em]e400867[/em][em]e400867[/em]
# @7 我以为只要足够真诚就会被对得起
# @中行 要是我考上跟她一样的大学，那我就读大专了[em]e400836[/em]
# @奇迹小猫 王者的标真的比陪我重要吗
# @消失的旧时光 yyds
# @姚若希什么时候90斤 听完这首你最喜欢的歌就睡觉啦
# @in my eyes 因为暗恋一个人，爱上周杰伦。\n现在早就不喜欢他了，\n可喜欢杰伦的歌却成了生命中的一种习惯。
# @WHN ╭══╮┌═══════════╯
# 让一让哈 ║ 这是对Jay的爱意存放专车╰⊙═⊙╯╰══⊙════⊙══╯ [em]e401148[/em][em]e401148[/em]
# @别看了 比你可爱 有时候晚上突然听起杰伦的歌 就会默默流眼泪 可是心里并不会难过
# @无晴 等你啊等啊等
# @Myaaaaaao. 害怕
# @宋芽芽 亲爱的周游 你一定要幸福
# @沉沦 不知不觉等你下课也成了一种习惯。
# @海。 你的感情收放自如  是天赋  我羡慕
# @Tennessine 爱你
# @多可悲 记得，那时候为了见你，每天缠着你给我找对象，每天去校门口接你，真的是等你下课呀。可是今天我们怎么就分开了啊，从身隔两地到心隔两地。@神奈子
# @宋芽芽 亲爱的周游 你一定要幸福
# @Myaaaaaao. 害怕
# @爱我十三年 要努力变成更好的人 理所当然的站在他身边
# @Echo 当我开始学会做蛋饼，才发现你不吃早餐
# @爱我十三年 要努力变成更好的人 理所当然的站在他身边

# %%
data['comment']['commenttotal']
# Out:
# 162977

# %%
import time

headers = {
  'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.132 Safari/537.36'
}

lasthotcommentid = ''
for pagenum in range(5):
    params = {
        'g_tk': '5381',
        'loginUin': '0',
        'hostUin': '0',
        'format': 'json',
        'inCharset': 'utf8',
        'outCharset': 'GB2312',
        'notice': '0',
        'platform': 'yqq.json',
        'needNewCode': '0',
        'cid': '205360772',
        'reqtype': '2',
        'biztype': '1',
        'topid': '212877900',
        'cmd': '8',
        'needmusiccrit': '0',
        'pagenum': pagenum,
        'pagesize': '25',
        'lasthotcommentid': lasthotcommentid,
        'domain': 'qq.com',
        'ct': '24',
        'cv': '10101010'}
    res = requests.get('https://c.y.qq.com/base/fcgi-bin/fcg_global_comment_h5.fcg', headers=headers, params=params)
    data = res.json()
    for item in data['comment']['commentlist']:
        if 'rootcommentcontent' in item: 
            print('{}：{}'.format(item['nick'], item['rootcommentcontent']))
    lasthotcommentid = data['comment']['commentlist'][-1]['commentid']
    time.sleep(1)
comments = set(comments)
for nick, content in comments:
    print('{}：{}'.format(nick, content))
# Out:
# T。：杰伦还是对自己没读好书而耿耿于怀
# Galaxy丶：很多催周杰伦出新专辑的 你们真听懂周董的心声了吗 他10年后的超越时间线的作品 真的听明白了吗[em]e400834[/em] 我唱告白气球你终于回了头也许只有从事艺术和音乐的人才能理解 周杰伦这种艺术家内心的孤独和无奈吧……
# Galaxy丶：我唱告白气球终于你回了头 艺术家的孤独和无奈啊 他也想我们听的是床边故事吧
# kendall0408：笑死，你根本配不上我，姐就是女王
# kendall0408：想起了高中那场没有结果的暗恋
# 。不考上大学不改名：你有看过我吗
# 无晴：又来了
# 喵哥：暗恋时《等你下课》
# 热恋时《告白气球》
# 分手时《不爱我就拉倒》
# 分手后《说好不哭》
# Jay还是那个最懂青春的人[em]e400867[/em][em]e400867[/em]
# 7：我以为只要足够真诚就会被对得起
# hj：要是我考上跟她一样的大学，那我就读大专了[em]e400836[/em]
# 奇迹小猫：王者的标真的比陪我重要吗
# 消失的旧时光：yyds
# 姚若希什么时候90斤：听完这首你最喜欢的歌就睡觉啦
# 安：因为暗恋一个人，爱上周杰伦。\n现在早就不喜欢他了，\n可喜欢杰伦的歌却成了生命中的一种习惯。
# WHN：╭══╮┌═══════════╯
# 让一让哈 ║ 这是对Jay的爱意存放专车╰⊙═⊙╯╰══⊙════⊙══╯ [em]e401148[/em][em]e401148[/em]
# 别看了 比你可爱：有时候晚上突然听起杰伦的歌 就会默默流眼泪 可是心里并不会难过
# 无晴：等你啊等啊等
# Luh kel.：害怕
# Luh kel.：亲爱的周游 你一定要幸福
# 沉沦：不知不觉等你下课也成了一种习惯。
# 海。：你的感情收放自如  是天赋  我羡慕
# Tennessine：爱你
# 多可悲：记得，那时候为了见你，每天缠着你给我找对象，每天去校门口接你，真的是等你下课呀。可是今天我们怎么就分开了啊，从身隔两地到心隔两地。@神奈子
# 宋芽芽：亲爱的周游 你一定要幸福
# Myaaaaaao.：害怕
# 网易让我充会员：要努力变成更好的人 理所当然的站在他身边
# Echo：当我开始学会做蛋饼，才发现你不吃早餐
# ...

# %%
#dic = {'a':{1.0,2,3.4},'b':{9.0,8,4},'c':{5,6,7}}

# %%
a = ['a','b','c','d']
b = [{0,1,2},{3,4,5},{8,7,19},{10,11,12}]

# %%
for m, n in zip(a,b):
    print (list(n)[2])
# Out:
# 2
# 5
# 7
# 12
